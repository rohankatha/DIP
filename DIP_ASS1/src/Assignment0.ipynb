# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Question - 1,2,3
# Loading images using OpenCV

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img1 = cv2.imread("/content/drive/MyDrive/DIP IMAGES/img1.jpg")
img2 = cv2.imread("/content/drive/MyDrive/DIP IMAGES/img2.jpg")
img3 = cv2.imread("/content/drive/MyDrive/DIP IMAGES/img3.jpg")
img4 = cv2.imread("/content/drive/MyDrive/DIP IMAGES/img4.jpg")


fig = plt.figure(figsize=(10, 7))
rows = 2
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
#plt.axis('off')


fig.add_subplot(rows, columns, 2)
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
#plt.axis('off')


fig.add_subplot(rows, columns, 3)
plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))
#plt.axis('off')


fig.add_subplot(rows, columns, 4)
plt.imshow(cv2.cvtColor(img4, cv2.COLOR_BGR2RGB))
#plt.axis('off')

# %% [markdown]
# # Question-4

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread("/content/drive/MyDrive/DIP IMAGES/baboon.jpg")

height,width  =  img.shape[0],img.shape[1]

img2 = np.empty([height,width])
for i in range(height):
  for j in range(width):
    img2[i][j] = (np.sum(img[i][j]))//3


plt.imshow(img2,cmap = 'gray')

# %% [markdown]
# # Question - 5

# %%
img = cv2.imread('/content/drive/MyDrive/DIP IMAGES/img3.jpg')
Height, Width,Channels = img.shape[0],img.shape[1],img.shape[2]
print('Height = ',Height,'Width =',Width,'Channels = ',Channels)
# Out:
# Height =  426 Width = 535 Channels =  3

# %% [markdown]
# #Question - 6

# %%
r,g,b = img[:,:,0].flatten(),img[:,:,1].flatten(),img[:,:,2].flatten()

range_r = [min(r),max(r)]
range_g = [min(g),max(g)]
range_b = [min(b),max(b)]

print('red =',range_r,'green =',range_g,'blue =',range_b )
# Out:
# red = [0, 255] green = [0, 255] blue = [0, 255]

# %% [markdown]
# From the range of red, green and blue channels it is observed their range lies between 0 and 255.
